# %% [markdown]
# # Grid Search Analysis (Alpha, Beta, Delta)
#
# This notebook analyzes the simulation results generated by the C++ code that performs a grid search over α, β, and δ. Each file corresponds to a specific combination and trial.

# %%
import os
from glob import glob

# Caminho da pasta onde estão os arquivos CSV
csv_folder = "C:/Supaero/Stage/Codigo3/Analysis/Data/Combination/2"

# Lista todos os arquivos .csv da pasta
arquivos_csv = glob(os.path.join(csv_folder, "*.csv"))

# Extrai apenas os nomes dos arquivos
nomes_arquivos = [os.path.basename(arquivo) for arquivo in arquivos_csv]

# Exibe a contagem e os nomes
print(f"🔍 Total de arquivos CSV encontrados: {len(nomes_arquivos)}\n")

for nome in nomes_arquivos:
    print(nome)
# Out:
# 🔍 Total de arquivos CSV encontrados: 36
#
# A2m_B0m_D10m_Data0.csv
# A2m_B0m_D10m_Data1.csv
# A2m_B0m_D10m_Data2.csv
# A2m_B0m_D15m_Data0.csv
# A2m_B0m_D15m_Data1.csv
# A2m_B0m_D15m_Data2.csv
# A2m_B0m_D20m_Data0.csv
# A2m_B0m_D20m_Data1.csv
# A2m_B0m_D20m_Data2.csv
# A2m_B0m_D5m_Data0.csv
# A2m_B0m_D5m_Data1.csv
# A2m_B0m_D5m_Data2.csv
# A3m_B0m_D10m_Data0.csv
# A3m_B0m_D10m_Data1.csv
# A3m_B0m_D10m_Data2.csv
# A3m_B0m_D15m_Data0.csv
# A3m_B0m_D15m_Data1.csv
# A3m_B0m_D15m_Data2.csv
# A3m_B0m_D20m_Data0.csv
# A3m_B0m_D20m_Data1.csv
# A3m_B0m_D20m_Data2.csv
# A3m_B0m_D5m_Data0.csv
# A3m_B0m_D5m_Data1.csv
# A3m_B0m_D5m_Data2.csv
# A4m_B0m_D10m_Data0.csv
# A4m_B0m_D10m_Data1.csv
# A4m_B0m_D10m_Data2.csv
# A4m_B0m_D15m_Data0.csv
# A4m_B0m_D15m_Data1.csv
# A4m_B0m_D15m_Data2.csv
# A4m_B0m_D20m_Data0.csv
# A4m_B0m_D20m_Data1.csv
# A4m_B0m_D20m_Data2.csv
# A4m_B0m_D5m_Data0.csv
# A4m_B0m_D5m_Data1.csv
# A4m_B0m_D5m_Data2.csv
